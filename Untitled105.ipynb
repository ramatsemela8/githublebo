# %% [markdown]
# <a href="https://colab.research.google.com/github/ramatsemela8/githublebo/blob/main/Untitled105.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
y = 2+5

print(y)
# Out:
# 7

# %%
import matplotlib.pyplot as plt
from google.colab import files

plt.plot([1, 2, 3], [2, 4, 6])
plt.title("Example Plot")
plt.savefig("example_plot.png", dpi=300, bbox_inches="tight")
files.download("example_plot.png")
